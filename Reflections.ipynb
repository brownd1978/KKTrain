# %% [markdown]
# # Hit classification

# %% [markdown]
# Set initial variables for the "suffix" identifier for the data set and "filePath" the relative path to the data files. Remember to add "/" to the end of your path, for example "../../TrkAna/43291981/"

# %% [markdown]
# In this notebook we use Keras and XGBoost to distinguish between hits from conversion electrons and hits from other particles

# %%
import os
import uproot 
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
import datetime
import tensorflow as tf
from pathlib import Path
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, ReLU
from tensorflow.keras.optimizers import SGD
import tensorflow.keras.layers
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
from xgboost import XGBClassifier
#import onnx
#import tf2onnx

# %%
rm -rf ./logs/

# %% [markdown]
# In our problem we have a different number of signal and background entries in our input dataset. There are several techniques avaialable for _unbalanced_ datasets. Here we are using the most naive one, which is just using $\min(N_{sig}, N_{bkg})$ events. Then, we divide our input into the _training_, _validation_, and _test_ datasets.  Note that the datasets must be pruned to the nearest multiple of the batch size, otherwise the gradient calculation fails.

# %%
input_dataset = np.empty
temp = np.empty
signal = np.empty
backgnd = np.empty
files = ["/global/cfs/cdirs/m3712/Mu2e/TA_CeEndpointMix1BBTriggerable.MDC2020ae_best_v1_3.root"]
#files = ["/global/u2/j/jasonguo/KKTrain/TADeMCeEDigis.root"]
#files = ["/global/cfs/cdirs/m3712/Mu2e/TADeM_CeEndpointMix1BBTriggerable.MDC2020ae_perfect_v1_3.root"]

data_fields = ["state", "udoca", "cdrift", "rdrift", "tottdrift", "wdot", "udocavar", "wdist", "uupos", "poca"]
mc_fields = ["rel"]

a = {field: [] for field in data_fields}
for field in mc_fields:
    a[field] = []
    
for batch in uproot.iterate(files,filter_name="/trk|trktsh|trktshmc/i"):
    #print("Fields available in 'trktsh':", ak.fields(batch["trktshmc"]))
    #cut = ak.sum(batch["trk.status"],axis=1) == 1
    
    cut = ((ak.sum(batch["trk.status"],axis=1) > 0) & ak.sum(batch["trk.goodfit"],axis=1)) == 1 #& 
           #(ak.sum(batch["trktshmc"]["startCode"], axis=1) == 167)) == 1
    
    batch["trktshmc"]["startCode"].type.show()
    #cut2 = ak.flatten(ak.flatten(batch["trktshmc"]["startCode"][ak.local_index(batch["trktshmc"]["startCode"]) < ak.num(batch["trktsh"]
    #        [data_fields[0]], axis = 2)][cut])).to_numpy()
    #cut2 = (cut2 == 167)
    for field in data_fields:
        a[field].append(ak.flatten(ak.flatten(batch["trktsh"][field][cut])).to_numpy())
    for field in mc_fields:
        a[field].append(ak.flatten(ak.flatten(batch["trktshmc"][field][ak.local_index(batch["trktshmc"][field]) < ak.num(batch["trktsh"]
            [data_fields[0]], axis = 2)][cut])).to_numpy())
for field in a:
    a[field] = np.concatenate(a[field])
    
udoca = np.absolute(a["udoca"])
sint = np.sqrt(1.0-a["wdot"]*a["wdot"])
plen = 6.25-a["cdrift"]*a["cdrift"]
pmin = np.repeat(0.25,plen.shape[0])
plen = np.sqrt(np.maximum(plen,pmin))
a["udocavar"] = np.absolute(a["udocavar"])
udocasig = np.sqrt(a["udocavar"])
print(a["poca"][0][0][0])
rho = np.array([np.sqrt(np.square(x[0][0]) + np.square(x[0][1])) for x in a["poca"]])
du = np.absolute(a["wdist"] - a["uupos"])


temp = np.vstack((udoca, a["cdrift"], udocasig, a["tottdrift"], du, rho)).T
if input_dataset is np.empty:
    input_dataset = temp
else:
    input_dataset = np.concatenate((input_dataset, temp))


#print("Processed file " + filename + " with %s hits"%a['state'].shape[0])
#print(a["rel"].shape)
#print(a["state"].shape)
#print (len(a["rel"]))
#print (len(a["state"]))
mcrel = np.array([x[0] for x in a["rel"]])
rand = np.random.random_sample([mcrel.shape[0]])

#print(udoca)
sig = (a["state"]>=-2) & (rand<0.05) & (mcrel==0) & (udoca < 50.0) & (du < 3000.0)
bkg = (a["state"]>=-2) & (mcrel==-1) & (udoca < 50.0) & ( du < 3000.0)
#print (np.sum(sig))
if signal is np.empty:
    signal = sig
    backgnd = bkg
else:
    signal = np.concatenate((signal,sig))
    backgnd = np.concatenate((backgnd,bkg))
        
nhits=len(input_dataset)
nsignal=signal.sum()
nbackgnd=backgnd.sum()
print("Total dataset %s hits, %s signal and %s background"%(nhits,nsignal,nbackgnd))
# Out:
# 8221 * var * var * int32
# 8221 * var * var * int32
# 8221 * var * var * int32
# 5280 * var * var * int32
# -184.94162
# Total dataset 1070059 hits, 50519 signal and 24358 background

# %%
min_len = min(len(input_dataset[signal]), len(input_dataset[backgnd]))
bsize=32
# I need to double the batch_size when truncating as we divide the sample in half later for training
tsize=2*bsize
min_len = (min_len - min_len%tsize)
print("Training on %s matched hits"%min_len)
signal_dataset = input_dataset[signal][:min_len]
bkg_dataset = input_dataset[backgnd][:min_len]

balanced_input = np.concatenate((signal_dataset, bkg_dataset))
y_balanced_input = np.concatenate((np.ones(signal_dataset.shape[0]), np.zeros(bkg_dataset.shape[0])))

n_variables = balanced_input.shape[1]

x_ce_train, x_ce_test, y_ce_train, y_ce_test = train_test_split(balanced_input, y_balanced_input, test_size=0.5, random_state=42)
x_ce_test, x_ce_valid, y_ce_test, y_ce_valid = train_test_split(x_ce_test, y_ce_test, test_size=0.5, random_state=42)
# Out:
# Training on 24320 matched hits

# %%
udoca_sig = []
udoca_back = []

for i in range(x_ce_train.shape[0]):
    if y_ce_train[i] == 1:
        udoca_sig.append(x_ce_train[i][0])
    else:
        udoca_back.append(x_ce_train[i][0])
plt.hist(udoca_sig,label="Unbiased DOCA Signal", bins=100,range=(0,15))
plt.hist(udoca_back,label="Unbiased DOCA Background", histtype='step', bins=100,range=(0,15))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
udoca_sig = []
tottdrift_sig = []
cdrift_sig = []
udocasig_sig = []
du_sig = []
rho_sig = []

for i in range(signal_dataset.shape[0]):
    udoca_sig.append(signal_dataset[i][0])
    
for i in range(signal_dataset.shape[0]):
    cdrift_sig.append(signal_dataset[i][1])
    
for i in range(signal_dataset.shape[0]):
    udocasig_sig.append(signal_dataset[i][2])

for i in range(signal_dataset.shape[0]):
    tottdrift_sig.append(signal_dataset[i][3])

for i in range(signal_dataset.shape[0]):
    du_sig.append(signal_dataset[i][4])

for i in range(signal_dataset.shape[0]):
    rho_sig.append(signal_dataset[i][5])

# %%
udoca_back = []
tottdrift_back = []
cdrift_back = []
udocasig_back = []
du_back = []
rho_back = []
    
for i in range(bkg_dataset.shape[0]):
    udoca_back.append(bkg_dataset[i][0])
    
for i in range(bkg_dataset.shape[0]):
    cdrift_back.append(bkg_dataset[i][1])
    
for i in range(bkg_dataset.shape[0]):
    udocasig_back.append(bkg_dataset[i][2])

for i in range(bkg_dataset.shape[0]):
    tottdrift_back.append(bkg_dataset[i][3])
    
for i in range(bkg_dataset.shape[0]):
    du_back.append(bkg_dataset[i][4])
    
for i in range(bkg_dataset.shape[0]):
    rho_back.append(bkg_dataset[i][5])

# %%
plt.hist(udoca_sig,label="Unbiased DOCA Signal", bins=100,range=(0,15))
plt.hist(udoca_back,label="Unbiased DOCA Background", histtype='step', bins=100,range=(0,15))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(cdrift_sig,label="Drift Radius Signal", bins=100,range=(-3.0,5.0))
plt.hist(cdrift_back,label="Drift Radius Background", histtype='step', bins=100, range=(-3.0,5.0))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(udocasig_sig,label="DOCA Variance Signal", bins=100,range=(0,2))
plt.hist(udocasig_back,label="DOCA Variance Background", histtype='step', bins=100,range=(0,2))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(tottdrift_sig,label="Time-Over-Threshold Drift Time Signal", bins=50, range=(0,40))
plt.hist(tottdrift_back,label="Time-Over-Threshold Drift Time Background", histtype='step', bins=50,range=(0,40))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(du_sig,label="WDist - Unbiased U Position Difference Signal", bins=50, range=(0,800))
plt.hist(du_back,label="WDist - Unbiased U Position Difference Background", histtype='step', bins=50, range=(0,800))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(rho_sig,label="Rho Signal", bins=50, range=(350,700))
plt.hist(rho_back,label="Rho Background", histtype='step', bins=50, range=(350,700))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Then, we concatenate each hit variables into a single, large numpy array. These arrays are then stacked in a single bi-dimensional array with `np.vstack`, which will be our input dataset used for the training of the machine learning algorithms.

# %% [markdown]
# Here we then assign a label to each hit as _signal_ or _background_, depending on the Monte Carlo truth information. Since the dimension of  `detshmc.rel._rel` is not guaranteed to be the same as the dimension of `detsh` we need to loop over all the entries.

# %% [markdown]
# ## Create and train a multi-layer perceptron

# %% [markdown]
# Here we create a _multi-layer perceptron_ (MLP) model which consists of 3 fully-connected (or _dense_) layers, each one followed by a _dropout_ layer, which helps to avoid overfitting. The model is trained using the [Adam](https://arxiv.org/abs/1412.6980) optimizer and trained for 50 epochs or until the validation loss doesn't improve for 5 epochs (`early_stop`). The model we save must be created first, with an explicit input layer with explicit batch_size, otherwise it can't be parsed by the TMVA::SOFIE parser we use to generate a C++ inference function downstream.

# %% [markdown]
# The output model must have batch_size=1, otherwise the SOFIE inference function will assume that many input variables at a time.  Training (gradient calculation) however is much more efficient with a larger batch size, so we construct a separate model for that.  After training and before saving, we'll copy the weights (which don't depend on batch_size) from the trained model to the output model.  This should be unnecessary in the next verison of ROOT.
#
# We should initialize the model by reading a previous iteration. TODO

# %%
# load previous training if it exists
suffix = "newdata"
modelfile = "models/TrainBkg" + suffix + ".h5"
if False:
    model = keras.models.load_model(modelfile)
    print("Loading model from file " +modelfile)
else:
    print("Creating model " +modelfile)
    lay0=Input(shape=(n_variables,),batch_size=bsize)
    lay1=Dense(2*n_variables, activation='relu')(lay0)
    lay2=Dense(2*n_variables, activation='relu')(lay1)
    lay3=Dense(2*n_variables, activation='relu')(lay2)
    lay4=Dense(1,activation='sigmoid')(lay3)
    model=Model(inputs=lay0,outputs=lay4)

opt = Adam(learning_rate=1e-3)
model.compile(loss='binary_crossentropy',metrics='accuracy',optimizer=opt)
early_stop = EarlyStopping(monitor='val_loss', patience=20, min_delta=1e-5, restore_best_weights=True)
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tensorflow.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

history = model.fit(x_ce_train, y_ce_train,
                          batch_size=bsize,
                          epochs=200,
                          verbose=1,
                          validation_data=(x_ce_valid, y_ce_valid),
                          callbacks=[early_stop, tensorboard_callback]
                         )
# Out:
# Creating model models/TrainBkgnewdata.h5
# 2024-10-02 14:51:00.979761: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-10-02 14:51:00.982163: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-02 14:51:00.997240: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2024-10-02 14:51:01.050159: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2024-10-02 14:51:01.050181: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2024-10-02 14:51:01.051550: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2024-10-02 14:51:01.105652: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-10-02 14:51:01.131560: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 1996130000 Hz
# Epoch 1/200
# 256/760 [=========>....................] - ETA: 0s - loss: 2.2872 - accuracy: 0.6914
# 2024-10-02 14:51:01.993752: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2024-10-02 14:51:01.993770: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2024-10-02 14:51:01.997476: I tensorflow/core/profiler/lib/profiler_session.cc:71] Profiler session collecting data.
# 2024-10-02 14:51:02.003857: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2024-10-02 14:51:02.012378: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/fit/20241002-145101/train/plugins/profile/2024_10_02_14_51_02
# 2024-10-02 14:51:02.014337: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to logs/fit/20241002-145101/train/plugins/profile/2024_10_02_14_51_02/login06.trace.json.gz
# 2024-10-02 14:51:02.022385: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/fit/20241002-145101/train/plugins/profile/2024_10_02_14_51_02
# 2024-10-02 14:51:02.022727: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to logs/fit/20241002-145101/train/plugins/profile/2024_10_02_14_51_02/login06.memory_profile.json.gz
# 2024-10-02 14:51:02.024147: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs/fit/20241002-145101/train/plugins/profile/2024_10_02_14_51_02Dumped tool data for xplane.pb to logs/fit/20241002-145101/train/plugins/profile/2024_10_02_14_51_02/login06.xplane.pb
# Dumped tool data for overview_page.pb to logs/fit/20241002-145101/train/plugins/profile/2024_10_02_14_51_02/login06.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs/fit/20241002-145101/train/plugins/profile/2024_10_02_14_51_02/login06.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs/fit/20241002-145101/train/plugins/profile/2024_10_02_14_51_02/login06.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs/fit/20241002-145101/train/plugins/profile/2024_10_02_14_51_02/login06.kernel_stats.pb
# 760/760 [==============================] - 4s 4ms/step - loss: 1.1771 - accuracy: 0.7859 - val_loss: 0.2659 - val_accuracy: 0.8961
# Epoch 2/200
# 760/760 [==============================] - 1s 839us/step - loss: 0.2140 - accuracy: 0.9267 - val_loss: 0.2523 - val_accuracy: 0.9125
# Epoch 3/200
# 760/760 [==============================] - 1s 896us/step - loss: 0.1880 - accuracy: 0.9383 - val_loss: 0.1569 - val_accuracy: 0.9531
# Epoch 4/200
# 760/760 [==============================] - 1s 828us/step - loss: 0.1708 - accuracy: 0.9450 - val_loss: 0.1419 - val_accuracy: 0.9537
# Epoch 5/200
# 760/760 [==============================] - 1s 768us/step - loss: 0.1641 - accuracy: 0.9491 - val_loss: 0.1382 - val_accuracy: 0.9577
# Epoch 6/200
# 760/760 [==============================] - 1s 755us/step - loss: 0.1595 - accuracy: 0.9524 - val_loss: 0.1325 - val_accuracy: 0.9601
# Epoch 7/200
# 760/760 [==============================] - 1s 771us/step - loss: 0.1501 - accuracy: 0.9552 - val_loss: 0.1308 - val_accuracy: 0.9649
# Epoch 8/200
# 760/760 [==============================] - 1s 753us/step - loss: 0.1415 - accuracy: 0.9556 - val_loss: 0.1230 - val_accuracy: 0.9636
# Epoch 9/200
# 760/760 [==============================] - 1s 777us/step - loss: 0.1437 - accuracy: 0.9551 - val_loss: 0.2219 - val_accuracy: 0.9243
# Epoch 10/200
# 760/760 [==============================] - 1s 763us/step - loss: 0.1403 - accuracy: 0.9572 - val_loss: 0.1230 - val_accuracy: 0.9641
# Epoch 11/200
# 760/760 [==============================] - 1s 739us/step - loss: 0.1305 - accuracy: 0.9612 - val_loss: 0.1461 - val_accuracy: 0.9609
# Epoch 12/200
# 760/760 [==============================] - 1s 711us/step - loss: 0.1364 - accuracy: 0.9601 - val_loss: 0.1247 - val_accuracy: 0.9614
# Epoch 13/200
# 760/760 [==============================] - 1s 724us/step - loss: 0.1341 - accuracy: 0.9591 - val_loss: 0.1156 - val_accuracy: 0.9660
# Epoch 14/200
# 760/760 [==============================] - 1s 734us/step - loss: 0.1338 - accuracy: 0.9608 - val_loss: 0.1240 - val_accuracy: 0.9615
# Epoch 15/200
# 760/760 [==============================] - 1s 743us/step - loss: 0.1233 - accuracy: 0.9608 - val_loss: 0.1444 - val_accuracy: 0.9563
# Epoch 16/200
# 760/760 [==============================] - 1s 740us/step - loss: 0.1323 - accuracy: 0.9588 - val_loss: 0.1512 - val_accuracy: 0.9599
# Epoch 17/200
# 760/760 [==============================] - 1s 763us/step - loss: 0.1296 - accuracy: 0.9600 - val_loss: 0.1560 - val_accuracy: 0.9512
# Epoch 18/200
# 760/760 [==============================] - 1s 765us/step - loss: 0.1294 - accuracy: 0.9612 - val_loss: 0.1189 - val_accuracy: 0.9656
# Epoch 19/200
# 760/760 [==============================] - 1s 736us/step - loss: 0.1314 - accuracy: 0.9607 - val_loss: 0.1389 - val_accuracy: 0.9568
# Epoch 20/200
# 760/760 [==============================] - 1s 768us/step - loss: 0.1252 - accuracy: 0.9610 - val_loss: 0.1154 - val_accuracy: 0.9641
# Epoch 21/200
# 760/760 [==============================] - 1s 738us/step - loss: 0.1215 - accuracy: 0.9619 - val_loss: 0.1114 - val_accuracy: 0.9682
# Epoch 22/200
# 760/760 [==============================] - 1s 752us/step - loss: 0.1248 - accuracy: 0.9615 - val_loss: 0.1943 - val_accuracy: 0.9410
# Epoch 23/200
# 760/760 [==============================] - 1s 714us/step - loss: 0.1227 - accuracy: 0.9620 - val_loss: 0.1293 - val_accuracy: 0.9618
# Epoch 24/200
# 760/760 [==============================] - 1s 757us/step - loss: 0.1245 - accuracy: 0.9612 - val_loss: 0.1378 - val_accuracy: 0.9579
# Epoch 25/200
# 760/760 [==============================] - 1s 744us/step - loss: 0.1215 - accuracy: 0.9617 - val_loss: 0.1164 - val_accuracy: 0.9653
# Epoch 26/200
# 760/760 [==============================] - 1s 792us/step - loss: 0.1227 - accuracy: 0.9636 - val_loss: 0.1084 - val_accuracy: 0.9685
# Epoch 27/200
# 760/760 [==============================] - 1s 757us/step - loss: 0.1212 - accuracy: 0.9626 - val_loss: 0.1153 - val_accuracy: 0.9645
# Epoch 28/200
# 760/760 [==============================] - 1s 784us/step - loss: 0.1150 - accuracy: 0.9646 - val_loss: 0.1203 - val_accuracy: 0.9623
# Epoch 29/200
# 760/760 [==============================] - 1s 740us/step - loss: 0.1196 - accuracy: 0.9634 - val_loss: 0.1201 - val_accuracy: 0.9623
# Epoch 30/200
# 760/760 [==============================] - 1s 713us/step - loss: 0.1230 - accuracy: 0.9616 - val_loss: 0.1094 - val_accuracy: 0.9675
# Epoch 31/200
# 760/760 [==============================] - 1s 720us/step - loss: 0.1152 - accuracy: 0.9653 - val_loss: 0.1155 - val_accuracy: 0.9644
# Epoch 32/200
# 760/760 [==============================] - 1s 747us/step - loss: 0.1180 - accuracy: 0.9644 - val_loss: 0.1193 - val_accuracy: 0.9639
# Epoch 33/200
# 760/760 [==============================] - 1s 722us/step - loss: 0.1177 - accuracy: 0.9637 - val_loss: 0.1435 - val_accuracy: 0.9543
# Epoch 34/200
# 760/760 [==============================] - 1s 747us/step - loss: 0.1205 - accuracy: 0.9612 - val_loss: 0.1075 - val_accuracy: 0.9681
# Epoch 35/200
# 760/760 [==============================] - 1s 763us/step - loss: 0.1172 - accuracy: 0.9631 - val_loss: 0.1097 - val_accuracy: 0.9695
# Epoch 36/200
# 760/760 [==============================] - 1s 752us/step - loss: 0.1122 - accuracy: 0.9670 - val_loss: 0.1348 - val_accuracy: 0.9590
# Epoch 37/200
# 760/760 [==============================] - 1s 845us/step - loss: 0.1155 - accuracy: 0.9634 - val_loss: 0.1146 - val_accuracy: 0.9653
# Epoch 38/200
# 760/760 [==============================] - 1s 747us/step - loss: 0.1248 - accuracy: 0.9608 - val_loss: 0.1098 - val_accuracy: 0.9674
# Epoch 39/200
# 760/760 [==============================] - 1s 742us/step - loss: 0.1175 - accuracy: 0.9636 - val_loss: 0.1061 - val_accuracy: 0.9679
# Epoch 40/200
# 760/760 [==============================] - 1s 767us/step - loss: 0.1161 - accuracy: 0.9652 - val_loss: 0.1115 - val_accuracy: 0.9680
# Epoch 41/200
# 760/760 [==============================] - 1s 749us/step - loss: 0.1140 - accuracy: 0.9647 - val_loss: 0.1158 - val_accuracy: 0.9651
# Epoch 42/200
# 760/760 [==============================] - 1s 765us/step - loss: 0.1127 - accuracy: 0.9659 - val_loss: 0.1134 - val_accuracy: 0.9650
# Epoch 43/200
# 760/760 [==============================] - 1s 725us/step - loss: 0.1153 - accuracy: 0.9638 - val_loss: 0.1373 - val_accuracy: 0.9595
# Epoch 44/200
# 760/760 [==============================] - 1s 760us/step - loss: 0.1138 - accuracy: 0.9655 - val_loss: 0.1157 - val_accuracy: 0.9688
# Epoch 45/200
# 760/760 [==============================] - 1s 732us/step - loss: 0.1191 - accuracy: 0.9647 - val_loss: 0.1163 - val_accuracy: 0.9641
# Epoch 46/200
# 760/760 [==============================] - 1s 747us/step - loss: 0.1133 - accuracy: 0.9648 - val_loss: 0.1202 - val_accuracy: 0.9663
# Epoch 47/200
# 760/760 [==============================] - 1s 753us/step - loss: 0.1110 - accuracy: 0.9654 - val_loss: 0.1097 - val_accuracy: 0.9679
# Epoch 48/200
# 760/760 [==============================] - 1s 754us/step - loss: 0.1164 - accuracy: 0.9630 - val_loss: 0.1096 - val_accuracy: 0.9689
# Epoch 49/200
# 760/760 [==============================] - 1s 735us/step - loss: 0.1127 - accuracy: 0.9654 - val_loss: 0.1185 - val_accuracy: 0.9657
# Epoch 50/200
# 760/760 [==============================] - 1s 770us/step - loss: 0.1111 - accuracy: 0.9653 - val_loss: 0.1080 - val_accuracy: 0.9690
# Epoch 51/200
# 760/760 [==============================] - 1s 860us/step - loss: 0.1141 - accuracy: 0.9658 - val_loss: 0.1178 - val_accuracy: 0.9650
# Epoch 52/200
# 760/760 [==============================] - 1s 888us/step - loss: 0.1147 - accuracy: 0.9636 - val_loss: 0.1110 - val_accuracy: 0.9669
# Epoch 53/200
# 760/760 [==============================] - 1s 827us/step - loss: 0.1135 - accuracy: 0.9650 - val_loss: 0.1274 - val_accuracy: 0.9604
# Epoch 54/200
# 760/760 [==============================] - 1s 791us/step - loss: 0.1154 - accuracy: 0.9637 - val_loss: 0.1240 - val_accuracy: 0.9607
# Epoch 55/200
# 760/760 [==============================] - 1s 792us/step - loss: 0.1113 - accuracy: 0.9664 - val_loss: 0.1069 - val_accuracy: 0.9707
# Epoch 56/200
# 760/760 [==============================] - 1s 796us/step - loss: 0.1029 - accuracy: 0.9687 - val_loss: 0.1202 - val_accuracy: 0.9615
# Epoch 57/200
# 760/760 [==============================] - 1s 796us/step - loss: 0.1082 - accuracy: 0.9672 - val_loss: 0.1127 - val_accuracy: 0.9667
# Epoch 58/200
# 760/760 [==============================] - 1s 811us/step - loss: 0.1069 - accuracy: 0.9676 - val_loss: 0.1057 - val_accuracy: 0.9712
# Epoch 59/200
# 760/760 [==============================] - 1s 851us/step - loss: 0.1089 - accuracy: 0.9674 - val_loss: 0.1077 - val_accuracy: 0.9681
# Epoch 60/200
# 760/760 [==============================] - 1s 754us/step - loss: 0.1135 - accuracy: 0.9648 - val_loss: 0.1180 - val_accuracy: 0.9631
# Epoch 61/200
# 760/760 [==============================] - 1s 844us/step - loss: 0.1080 - accuracy: 0.9667 - val_loss: 0.1085 - val_accuracy: 0.9701
# Epoch 62/200
# 760/760 [==============================] - 1s 885us/step - loss: 0.1116 - accuracy: 0.9654 - val_loss: 0.1187 - val_accuracy: 0.9621
# Epoch 63/200
# 760/760 [==============================] - 1s 826us/step - loss: 0.1071 - accuracy: 0.9669 - val_loss: 0.1358 - val_accuracy: 0.9561
# Epoch 64/200
# 760/760 [==============================] - 1s 862us/step - loss: 0.1071 - accuracy: 0.9662 - val_loss: 0.1169 - val_accuracy: 0.9654
# Epoch 65/200
# 760/760 [==============================] - 1s 810us/step - loss: 0.1046 - accuracy: 0.9673 - val_loss: 0.1023 - val_accuracy: 0.9715
# Epoch 66/200
# 760/760 [==============================] - 1s 742us/step - loss: 0.1094 - accuracy: 0.9656 - val_loss: 0.1101 - val_accuracy: 0.9678
# Epoch 67/200
# 760/760 [==============================] - 1s 747us/step - loss: 0.1046 - accuracy: 0.9663 - val_loss: 0.1039 - val_accuracy: 0.9701
# Epoch 68/200
# 760/760 [==============================] - 1s 749us/step - loss: 0.1104 - accuracy: 0.9654 - val_loss: 0.1209 - val_accuracy: 0.9654
# Epoch 69/200
# 760/760 [==============================] - 1s 807us/step - loss: 0.1067 - accuracy: 0.9674 - val_loss: 0.1053 - val_accuracy: 0.9706
# Epoch 70/200
# 760/760 [==============================] - 1s 803us/step - loss: 0.1038 - accuracy: 0.9694 - val_loss: 0.1020 - val_accuracy: 0.9719
# Epoch 71/200
# 760/760 [==============================] - 1s 801us/step - loss: 0.1004 - accuracy: 0.9682 - val_loss: 0.1026 - val_accuracy: 0.9708
# Epoch 72/200
# 760/760 [==============================] - 1s 816us/step - loss: 0.1009 - accuracy: 0.9693 - val_loss: 0.1090 - val_accuracy: 0.9677
# Epoch 73/200
# 760/760 [==============================] - 1s 791us/step - loss: 0.1038 - accuracy: 0.9678 - val_loss: 0.1032 - val_accuracy: 0.9701
# Epoch 74/200
# 760/760 [==============================] - 1s 798us/step - loss: 0.1029 - accuracy: 0.9698 - val_loss: 0.1012 - val_accuracy: 0.9721
# Epoch 75/200
# 760/760 [==============================] - 1s 831us/step - loss: 0.1030 - accuracy: 0.9678 - val_loss: 0.0981 - val_accuracy: 0.9714
# Epoch 76/200
# 760/760 [==============================] - 1s 789us/step - loss: 0.0980 - accuracy: 0.9707 - val_loss: 0.1093 - val_accuracy: 0.9658
# Epoch 77/200
# 760/760 [==============================] - 1s 818us/step - loss: 0.1003 - accuracy: 0.9692 - val_loss: 0.0956 - val_accuracy: 0.9723
# Epoch 78/200
# 760/760 [==============================] - 1s 748us/step - loss: 0.1026 - accuracy: 0.9690 - val_loss: 0.1056 - val_accuracy: 0.9688
# Epoch 79/200
# 760/760 [==============================] - 1s 758us/step - loss: 0.1007 - accuracy: 0.9695 - val_loss: 0.1040 - val_accuracy: 0.9690
# Epoch 80/200
# 760/760 [==============================] - 1s 768us/step - loss: 0.0981 - accuracy: 0.9699 - val_loss: 0.1076 - val_accuracy: 0.9664
# Epoch 81/200
# 760/760 [==============================] - 1s 749us/step - loss: 0.0964 - accuracy: 0.9706 - val_loss: 0.0947 - val_accuracy: 0.9727
# Epoch 82/200
# 760/760 [==============================] - 1s 766us/step - loss: 0.0929 - accuracy: 0.9718 - val_loss: 0.1176 - val_accuracy: 0.9641
# Epoch 83/200
# 760/760 [==============================] - 1s 768us/step - loss: 0.1016 - accuracy: 0.9693 - val_loss: 0.1042 - val_accuracy: 0.9715
# Epoch 84/200
# 760/760 [==============================] - 1s 767us/step - loss: 0.0943 - accuracy: 0.9711 - val_loss: 0.0920 - val_accuracy: 0.9734
# Epoch 85/200
# 760/760 [==============================] - 1s 828us/step - loss: 0.0890 - accuracy: 0.9729 - val_loss: 0.1308 - val_accuracy: 0.9597
# Epoch 86/200
# 760/760 [==============================] - 1s 798us/step - loss: 0.0977 - accuracy: 0.9705 - val_loss: 0.0895 - val_accuracy: 0.9746
# Epoch 87/200
# 760/760 [==============================] - 1s 859us/step - loss: 0.0924 - accuracy: 0.9720 - val_loss: 0.0869 - val_accuracy: 0.9754
# Epoch 88/200
# 760/760 [==============================] - 1s 758us/step - loss: 0.0913 - accuracy: 0.9718 - val_loss: 0.0927 - val_accuracy: 0.9734
# Epoch 89/200
# 760/760 [==============================] - 1s 738us/step - loss: 0.0906 - accuracy: 0.9728 - val_loss: 0.0964 - val_accuracy: 0.9709
# Epoch 90/200
# 760/760 [==============================] - 1s 754us/step - loss: 0.0931 - accuracy: 0.9716 - val_loss: 0.0889 - val_accuracy: 0.9761
# Epoch 91/200
# 760/760 [==============================] - 1s 745us/step - loss: 0.0874 - accuracy: 0.9737 - val_loss: 0.0837 - val_accuracy: 0.9766
# Epoch 92/200
# 760/760 [==============================] - 1s 714us/step - loss: 0.0924 - accuracy: 0.9723 - val_loss: 0.0931 - val_accuracy: 0.9733
# Epoch 93/200
# 760/760 [==============================] - 1s 740us/step - loss: 0.0893 - accuracy: 0.9736 - val_loss: 0.0904 - val_accuracy: 0.9745
# Epoch 94/200
# 760/760 [==============================] - 1s 767us/step - loss: 0.0856 - accuracy: 0.9743 - val_loss: 0.0875 - val_accuracy: 0.9746
# Epoch 95/200
# 760/760 [==============================] - 1s 749us/step - loss: 0.0897 - accuracy: 0.9721 - val_loss: 0.0917 - val_accuracy: 0.9722
# Epoch 96/200
# 760/760 [==============================] - 1s 711us/step - loss: 0.0858 - accuracy: 0.9742 - val_loss: 0.0845 - val_accuracy: 0.9764
# Epoch 97/200
# 760/760 [==============================] - 1s 792us/step - loss: 0.0862 - accuracy: 0.9747 - val_loss: 0.0844 - val_accuracy: 0.9766
# Epoch 98/200
# 760/760 [==============================] - 1s 740us/step - loss: 0.0837 - accuracy: 0.9751 - val_loss: 0.0833 - val_accuracy: 0.9763
# Epoch 99/200
# 760/760 [==============================] - 1s 754us/step - loss: 0.0853 - accuracy: 0.9737 - val_loss: 0.0883 - val_accuracy: 0.9753
# Epoch 100/200
# 760/760 [==============================] - 1s 785us/step - loss: 0.0913 - accuracy: 0.9728 - val_loss: 0.0858 - val_accuracy: 0.9753
# Epoch 101/200
# 760/760 [==============================] - 1s 773us/step - loss: 0.0882 - accuracy: 0.9740 - val_loss: 0.0817 - val_accuracy: 0.9773
# Epoch 102/200
# 760/760 [==============================] - 1s 756us/step - loss: 0.0891 - accuracy: 0.9736 - val_loss: 0.0891 - val_accuracy: 0.9748
# Epoch 103/200
# 760/760 [==============================] - 1s 744us/step - loss: 0.0866 - accuracy: 0.9729 - val_loss: 0.0942 - val_accuracy: 0.9726
# Epoch 104/200
# 760/760 [==============================] - 1s 791us/step - loss: 0.0848 - accuracy: 0.9750 - val_loss: 0.0856 - val_accuracy: 0.9767
# Epoch 105/200
# 760/760 [==============================] - 1s 739us/step - loss: 0.0840 - accuracy: 0.9746 - val_loss: 0.0845 - val_accuracy: 0.9757
# Epoch 106/200
# 760/760 [==============================] - 1s 744us/step - loss: 0.0850 - accuracy: 0.9747 - val_loss: 0.0913 - val_accuracy: 0.9744
# Epoch 107/200
# 760/760 [==============================] - 1s 777us/step - loss: 0.0825 - accuracy: 0.9763 - val_loss: 0.0812 - val_accuracy: 0.9774
# Epoch 108/200
# 760/760 [==============================] - 1s 741us/step - loss: 0.0867 - accuracy: 0.9738 - val_loss: 0.0915 - val_accuracy: 0.9734
# Epoch 109/200
# 760/760 [==============================] - 1s 724us/step - loss: 0.0823 - accuracy: 0.9764 - val_loss: 0.0864 - val_accuracy: 0.9749
# Epoch 110/200
# 760/760 [==============================] - 1s 920us/step - loss: 0.0815 - accuracy: 0.9750 - val_loss: 0.0861 - val_accuracy: 0.9768
# Epoch 111/200
# 760/760 [==============================] - 1s 752us/step - loss: 0.0847 - accuracy: 0.9747 - val_loss: 0.0823 - val_accuracy: 0.9775
# Epoch 112/200
# 760/760 [==============================] - 1s 772us/step - loss: 0.0842 - accuracy: 0.9752 - val_loss: 0.0941 - val_accuracy: 0.9754
# Epoch 113/200
# 760/760 [==============================] - 1s 829us/step - loss: 0.0853 - accuracy: 0.9751 - val_loss: 0.0849 - val_accuracy: 0.9768
# Epoch 114/200
# 760/760 [==============================] - 1s 725us/step - loss: 0.0805 - accuracy: 0.9768 - val_loss: 0.0869 - val_accuracy: 0.9771
# Epoch 115/200
# 760/760 [==============================] - 1s 703us/step - loss: 0.0847 - accuracy: 0.9743 - val_loss: 0.0815 - val_accuracy: 0.9779
# Epoch 116/200
# 760/760 [==============================] - 1s 730us/step - loss: 0.0787 - accuracy: 0.9765 - val_loss: 0.0845 - val_accuracy: 0.9765
# Epoch 117/200
# 760/760 [==============================] - 1s 772us/step - loss: 0.0863 - accuracy: 0.9747 - val_loss: 0.0890 - val_accuracy: 0.9762
# Epoch 118/200
# 760/760 [==============================] - 1s 904us/step - loss: 0.0826 - accuracy: 0.9764 - val_loss: 0.0861 - val_accuracy: 0.9754
# Epoch 119/200
# 760/760 [==============================] - 1s 785us/step - loss: 0.0872 - accuracy: 0.9740 - val_loss: 0.0857 - val_accuracy: 0.9768
# Epoch 120/200
# 760/760 [==============================] - 1s 803us/step - loss: 0.0819 - accuracy: 0.9754 - val_loss: 0.0880 - val_accuracy: 0.9744
# Epoch 121/200
# 760/760 [==============================] - 1s 784us/step - loss: 0.0829 - accuracy: 0.9755 - val_loss: 0.0818 - val_accuracy: 0.9774
# Epoch 122/200
# 760/760 [==============================] - 1s 764us/step - loss: 0.0785 - accuracy: 0.9760 - val_loss: 0.0850 - val_accuracy: 0.9771
# Epoch 123/200
# 760/760 [==============================] - 1s 734us/step - loss: 0.0873 - accuracy: 0.9746 - val_loss: 0.0816 - val_accuracy: 0.9774
# Epoch 124/200
# 760/760 [==============================] - 1s 754us/step - loss: 0.0818 - accuracy: 0.9755 - val_loss: 0.0921 - val_accuracy: 0.9739
# Epoch 125/200
# 760/760 [==============================] - 1s 758us/step - loss: 0.0800 - accuracy: 0.9768 - val_loss: 0.0912 - val_accuracy: 0.9752
# Epoch 126/200
# 760/760 [==============================] - 1s 750us/step - loss: 0.0882 - accuracy: 0.9744 - val_loss: 0.0834 - val_accuracy: 0.9762
# Epoch 127/200
# 760/760 [==============================] - 1s 731us/step - loss: 0.0778 - accuracy: 0.9767 - val_loss: 0.0893 - val_accuracy: 0.9753

# %%
plt.plot(history.history['val_loss'],label="val loss")
plt.plot(history.history['loss'],label="loss")
plt.legend()

# %load_ext tensorboard
#rm -rf ./logs/
# %tensorboard --logdir logs/fit
# Out:
# ERROR: Could not find `tensorboard`. Please ensure that your PATH
# contains an executable `tensorboard` program, or explicitly specify
# the path to a TensorBoard binary by setting the `TENSORBOARD_BINARY`
# environment variable.

# %% [markdown]
# ## Create and train a Boosted Decision Tree
# Here, instead of using a MLP, we use a [_Gradient Boosted Decision Tree_](https://xgboost.readthedocs.io/en/stable/) (BDT) to distinguish between signal (true CE hits) and background (fake CE hits). We use the defualt hyperparameters.

# %%
model_xgboost = XGBClassifier(use_label_encoder=False)
model_xgboost.fit(x_ce_train, y_ce_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %% [markdown]
# Here we can finally apply our two models (the MLP and the BDT) to our test datasets and create the corresponding ROC curves.

# %%
#prediction_ce = model.predict(x_ce_test).ravel()
prediction_ce = model.predict(x_ce_test)
fpr_ce, tpr_ce, th_ce = roc_curve(y_ce_test,  prediction_ce)
auc_ce = roc_auc_score(y_ce_test, prediction_ce)

# %%
prediction_xgboost = model_xgboost.predict_proba(x_ce_test)[:,1]
fpr_xgboost, tpr_xgboost, th_xgboost = roc_curve(y_ce_test,  prediction_xgboost)
auc_xgboost = roc_auc_score(y_ce_test, prediction_xgboost)

# %% [markdown]
# The plot of the ROC curves clearly shows that the BDT outperforms the MLP. In principle, however, it should be possible to improve the MLP performances by optimizing the hyperparameters (learning rate, hidden layers, activation functions, etc.).

# %%
fig, ax = plt.subplots(1,1)
ax.plot(tpr_ce,1-fpr_ce,label=f'MLP AUC: {auc_ce:.4f}')
ax.plot(tpr_xgboost,1-fpr_xgboost,label=f'BDT AUC: {auc_xgboost:.4f}')

ax.legend()
ax.set_aspect("equal")
ax.set_xlabel("Signal efficiency")
ax.set_ylabel("Background rejection")
ax.set_xlim(0.8,1.05)
ax.set_ylim(0.8,1.05)

fig.savefig("plots/TrainBkg" + suffix + ".pdf")

# %% [markdown]
# Now we save our model in HDF5 format.  This can be used as input to the SOFIE parser.  Note that the kernel must be restarted when saving this file, as re-running individual cells increments the layer numbers in the hdf5 file, causing the SOFIE parser to fail.  This causes the spurious tensorflow warning about the model not having been built.

# %%
model.save(modelfile)
print("model saved to " +modelfile)
model.summary()
# Out:
# model saved to models/TrainBkgnewdata.h5
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(32, 6)]                 0
# _________________________________________________________________
# dense (Dense)                (32, 12)                  84
# _________________________________________________________________
# dense_1 (Dense)              (32, 12)                  156
# _________________________________________________________________
# dense_2 (Dense)              (32, 12)                  156
# _________________________________________________________________
# dense_3 (Dense)              (32, 1)                   13
# =================================================================
# Total params: 409
# Trainable params: 409
# Non-trainable params: 0
# _________________________________________________________________
