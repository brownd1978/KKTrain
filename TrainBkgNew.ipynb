# %% [markdown]
# # Hit classification

# %% [markdown]
# Set initial variables for the "suffix" identifier for the data set and "filePath" the relative path to the data files. Remember to add "/" to the end of your path, for example "../../TrkAna/43291981/"

# %% [markdown]
# In this notebook we use Keras and XGBoost to distinguish between hits from conversion electrons and hits from other particles

# %%
import os
import uproot 
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
import datetime
import tensorflow as tf
from pathlib import Path
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, ReLU
from tensorflow.keras.optimizers import SGD
import tensorflow.keras.layers
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
from xgboost import XGBClassifier
import onnx
import tf2onnx

# %%
rm -rf ./logs/

# %% [markdown]
# In our problem we have a different number of signal and background entries in our input dataset. There are several techniques avaialable for _unbalanced_ datasets. Here we are using the most naive one, which is just using $\min(N_{sig}, N_{bkg})$ events. Then, we divide our input into the _training_, _validation_, and _test_ datasets.  Note that the datasets must be pruned to the nearest multiple of the batch size, otherwise the gradient calculation fails.

# %%
input_dataset = np.empty
temp = np.empty
signal = np.empty
backgnd = np.empty
files = ["/global/cfs/cdirs/m3712/Mu2e/TA_CeEndpointMix1BBTriggerable.MDC2020ae_best_v1_3.root"]
#files = ["/global/u2/j/jasonguo/KKTrain/TADeMCeEDigis.root"]
#files = ["/global/cfs/cdirs/m3712/Mu2e/TADeM_CeEndpointMix1BBTriggerable.MDC2020ae_perfect_v1_3.root"]

data_fields = ["state", "udoca", "cdrift", "rdrift", "tottdrift", "wdot", "udocavar", "wdist", "uupos", "poca"]
mc_fields = ["rel"]

a = {field: [] for field in data_fields}
for field in mc_fields:
    a[field] = []
    
for batch in uproot.iterate(files,filter_name="/trk|trktsh|trktshmc/i"):
    #print("Fields available in 'trktsh':", ak.fields(batch["trktshmc"]))
    #cut = ak.sum(batch["trk.status"],axis=1) == 1
    
    cut = ((ak.sum(batch["trk.status"],axis=1) > 0) & ak.sum(batch["trk.goodfit"],axis=1)) == 1 #& 
           #(ak.sum(batch["trktshmc"]["startCode"], axis=1) == 167)) == 1
    
    batch["trktshmc"]["startCode"].type.show()
    #cut2 = ak.flatten(ak.flatten(batch["trktshmc"]["startCode"][ak.local_index(batch["trktshmc"]["startCode"]) < ak.num(batch["trktsh"]
    #        [data_fields[0]], axis = 2)][cut])).to_numpy()
    #cut2 = (cut2 == 167)
    for field in data_fields:
        a[field].append(ak.flatten(ak.flatten(batch["trktsh"][field][cut])).to_numpy())
    for field in mc_fields:
        a[field].append(ak.flatten(ak.flatten(batch["trktshmc"][field][ak.local_index(batch["trktshmc"][field]) < ak.num(batch["trktsh"]
            [data_fields[0]], axis = 2)][cut])).to_numpy())
for field in a:
    a[field] = np.concatenate(a[field])
    
udoca = np.absolute(a["udoca"])
sint = np.sqrt(1.0-a["wdot"]*a["wdot"])
plen = 6.25-a["cdrift"]*a["cdrift"]
pmin = np.repeat(0.25,plen.shape[0])
plen = np.sqrt(np.maximum(plen,pmin))
a["udocavar"] = np.absolute(a["udocavar"])
udocasig = np.sqrt(a["udocavar"])
print(a["poca"][0][0][0])
rho = np.array([np.sqrt(np.square(x[0][0]) + np.square(x[0][1])) for x in a["poca"]])
du = np.absolute(a["wdist"] - a["uupos"])


temp = np.vstack((udoca, a["cdrift"], udocasig, a["tottdrift"], du, rho)).T
if input_dataset is np.empty:
    input_dataset = temp
else:
    input_dataset = np.concatenate((input_dataset, temp))


#print("Processed file " + filename + " with %s hits"%a['state'].shape[0])
#print(a["rel"].shape)
#print(a["state"].shape)
#print (len(a["rel"]))
#print (len(a["state"]))
mcrel = np.array([x[0] for x in a["rel"]])
rand = np.random.random_sample([mcrel.shape[0]])

#print(udoca)
sig = (a["state"]>=-2) & (rand<0.05) & (mcrel==0) & (udoca < 50.0) & (du < 3000.0)
bkg = (a["state"]>=-2) & (mcrel==-1) & (udoca < 50.0) & ( du < 3000.0)
#print (np.sum(sig))
if signal is np.empty:
    signal = sig
    backgnd = bkg
else:
    signal = np.concatenate((signal,sig))
    backgnd = np.concatenate((backgnd,bkg))
        
nhits=len(input_dataset)
nsignal=signal.sum()
nbackgnd=backgnd.sum()
print("Total dataset %s hits, %s signal and %s background"%(nhits,nsignal,nbackgnd))
# Out:
# 8221 * var * var * int32
# 8221 * var * var * int32
# 8221 * var * var * int32
# 5280 * var * var * int32
# -184.94162
# Total dataset 1070059 hits, 50781 signal and 24358 background

# %%
min_len = min(len(input_dataset[signal]), len(input_dataset[backgnd]))
bsize=32
# I need to double the batch_size when truncating as we divide the sample in half later for training
tsize=2*bsize
min_len = (min_len - min_len%tsize)
print("Training on %s matched hits"%min_len)
signal_dataset = input_dataset[signal][:min_len]
bkg_dataset = input_dataset[backgnd][:min_len]

balanced_input = np.concatenate((signal_dataset, bkg_dataset))
y_balanced_input = np.concatenate((np.ones(signal_dataset.shape[0]), np.zeros(bkg_dataset.shape[0])))

n_variables = balanced_input.shape[1]

x_ce_train, x_ce_test, y_ce_train, y_ce_test = train_test_split(balanced_input, y_balanced_input, test_size=0.5, random_state=42)
x_ce_test, x_ce_valid, y_ce_test, y_ce_valid = train_test_split(x_ce_test, y_ce_test, test_size=0.5, random_state=42)
# Out:
# Training on 24320 matched hits

# %%
udoca_sig = []
udoca_back = []

for i in range(x_ce_train.shape[0]):
    if y_ce_train[i] == 1:
        udoca_sig.append(x_ce_train[i][0])
    else:
        udoca_back.append(x_ce_train[i][0])
plt.hist(udoca_sig,label="Unbiased DOCA Signal", bins=100,range=(0,15))
plt.hist(udoca_back,label="Unbiased DOCA Background", histtype='step', bins=100,range=(0,15))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
udoca_sig = []
tottdrift_sig = []
cdrift_sig = []
udocasig_sig = []
du_sig = []
rho_sig = []

for i in range(signal_dataset.shape[0]):
    udoca_sig.append(signal_dataset[i][0])
    
for i in range(signal_dataset.shape[0]):
    cdrift_sig.append(signal_dataset[i][1])
    
for i in range(signal_dataset.shape[0]):
    udocasig_sig.append(signal_dataset[i][2])

for i in range(signal_dataset.shape[0]):
    tottdrift_sig.append(signal_dataset[i][3])

for i in range(signal_dataset.shape[0]):
    du_sig.append(signal_dataset[i][4])

for i in range(signal_dataset.shape[0]):
    rho_sig.append(signal_dataset[i][5])

# %%
udoca_back = []
tottdrift_back = []
cdrift_back = []
udocasig_back = []
du_back = []
rho_back = []
    
for i in range(bkg_dataset.shape[0]):
    udoca_back.append(bkg_dataset[i][0])
    
for i in range(bkg_dataset.shape[0]):
    cdrift_back.append(bkg_dataset[i][1])
    
for i in range(bkg_dataset.shape[0]):
    udocasig_back.append(bkg_dataset[i][2])

for i in range(bkg_dataset.shape[0]):
    tottdrift_back.append(bkg_dataset[i][3])
    
for i in range(bkg_dataset.shape[0]):
    du_back.append(bkg_dataset[i][4])
    
for i in range(bkg_dataset.shape[0]):
    rho_back.append(bkg_dataset[i][5])

# %%
plt.hist(udoca_sig,label="Unbiased DOCA Signal", bins=100,range=(0,15))
plt.hist(udoca_back,label="Unbiased DOCA Background", histtype='step', bins=100,range=(0,15))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(cdrift_sig,label="Drift Radius Signal", bins=50,range=(-3.0,5.0))
plt.hist(cdrift_back,label="Drift Radius Background", histtype='step', bins=50, range=(-3.0,5.0))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(udocasig_sig,label="DOCA Variance Signal", bins=50,range=(0,5))
plt.hist(udocasig_back,label="DOCA Variance Background", histtype='step', bins=50,range=(0,5))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(tottdrift_sig,label="Time-Over-Threshold Drift Time Signal", bins=50, range=(0,40))
plt.hist(tottdrift_back,label="Time-Over-Threshold Drift Time Background", histtype='step', bins=50,range=(0,40))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(du_sig,label="WDist - Unbiased U Position Difference Signal", bins=50, range=(0,800))
plt.hist(du_back,label="WDist - Unbiased U Position Difference Background", histtype='step', bins=50, range=(0,800))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(rho_sig,label="Rho Signal", bins=50, range=(350,700))
plt.hist(rho_back,label="Rho Background", histtype='step', bins=50, range=(350,700))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Then, we concatenate each hit variables into a single, large numpy array. These arrays are then stacked in a single bi-dimensional array with `np.vstack`, which will be our input dataset used for the training of the machine learning algorithms.

# %% [markdown]
# Here we then assign a label to each hit as _signal_ or _background_, depending on the Monte Carlo truth information. Since the dimension of  `detshmc.rel._rel` is not guaranteed to be the same as the dimension of `detsh` we need to loop over all the entries.

# %% [markdown]
# ## Create and train a multi-layer perceptron

# %% [markdown]
# Here we create a _multi-layer perceptron_ (MLP) model which consists of 3 fully-connected (or _dense_) layers, each one followed by a _dropout_ layer, which helps to avoid overfitting. The model is trained using the [Adam](https://arxiv.org/abs/1412.6980) optimizer and trained for 50 epochs or until the validation loss doesn't improve for 5 epochs (`early_stop`). The model we save must be created first, with an explicit input layer with explicit batch_size, otherwise it can't be parsed by the TMVA::SOFIE parser we use to generate a C++ inference function downstream.

# %% [markdown]
# The output model must have batch_size=1, otherwise the SOFIE inference function will assume that many input variables at a time.  Training (gradient calculation) however is much more efficient with a larger batch size, so we construct a separate model for that.  After training and before saving, we'll copy the weights (which don't depend on batch_size) from the trained model to the output model.  This should be unnecessary in the next verison of ROOT.
#
# We should initialize the model by reading a previous iteration. TODO

# %%
# load previous training if it exists
suffix = "newdata"
modelfile = "models/TrainBkg" + suffix + ".h5"
if False:
    model = keras.models.load_model(modelfile)
    print("Loading model from file " +modelfile)
else:
    print("Creating model " +modelfile)
    lay0=Input(shape=(n_variables,),batch_size=bsize)
    lay1=Dense(2*n_variables, activation='relu')(lay0)
    lay2=Dense(2*n_variables, activation='relu')(lay1)
    lay3=Dense(2*n_variables, activation='relu')(lay2)
    lay4=Dense(1,activation='sigmoid')(lay3)
    model=Model(inputs=lay0,outputs=lay4)

opt = Adam(learning_rate=1e-3)
model.compile(loss='binary_crossentropy',metrics='accuracy',optimizer=opt)
early_stop = EarlyStopping(monitor='val_loss', patience=20, min_delta=1e-5, restore_best_weights=True)
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tensorflow.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

history = model.fit(x_ce_train, y_ce_train,
                          batch_size=bsize,
                          epochs=200,
                          verbose=1,
                          validation_data=(x_ce_valid, y_ce_valid),
                          callbacks=[early_stop, tensorboard_callback]
                         )
# Out:
# Creating model models/TrainBkgnewdata.h5
# Epoch 1/200
# 2024-10-02 12:54:04.262202: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2024-10-02 12:54:04.262217: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2024-10-02 12:54:04.262239: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 317/760 [===========>..................] - ETA: 0s - loss: 4.0041 - accuracy: 0.7171
# 2024-10-02 12:54:04.632521: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2024-10-02 12:54:04.632535: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2024-10-02 12:54:04.649721: I tensorflow/core/profiler/lib/profiler_session.cc:71] Profiler session collecting data.
# 2024-10-02 12:54:04.650365: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2024-10-02 12:54:04.651890: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/fit/20241002-125404/train/plugins/profile/2024_10_02_12_54_04
# 2024-10-02 12:54:04.652922: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to logs/fit/20241002-125404/train/plugins/profile/2024_10_02_12_54_04/login26.trace.json.gz
# 2024-10-02 12:54:04.653845: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/fit/20241002-125404/train/plugins/profile/2024_10_02_12_54_04
# 2024-10-02 12:54:04.654084: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to logs/fit/20241002-125404/train/plugins/profile/2024_10_02_12_54_04/login26.memory_profile.json.gz
# 2024-10-02 12:54:04.655281: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs/fit/20241002-125404/train/plugins/profile/2024_10_02_12_54_04Dumped tool data for xplane.pb to logs/fit/20241002-125404/train/plugins/profile/2024_10_02_12_54_04/login26.xplane.pb
# Dumped tool data for overview_page.pb to logs/fit/20241002-125404/train/plugins/profile/2024_10_02_12_54_04/login26.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs/fit/20241002-125404/train/plugins/profile/2024_10_02_12_54_04/login26.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs/fit/20241002-125404/train/plugins/profile/2024_10_02_12_54_04/login26.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs/fit/20241002-125404/train/plugins/profile/2024_10_02_12_54_04/login26.kernel_stats.pb
# 760/760 [==============================] - 1s 960us/step - loss: 2.1917 - accuracy: 0.8047 - val_loss: 0.2405 - val_accuracy: 0.9055
# Epoch 2/200
# 760/760 [==============================] - 1s 707us/step - loss: 0.2176 - accuracy: 0.9294 - val_loss: 0.1774 - val_accuracy: 0.9376
# Epoch 3/200
# 760/760 [==============================] - 1s 750us/step - loss: 0.1891 - accuracy: 0.9425 - val_loss: 0.1547 - val_accuracy: 0.9522
# Epoch 4/200
# 760/760 [==============================] - 1s 728us/step - loss: 0.1857 - accuracy: 0.9431 - val_loss: 0.1925 - val_accuracy: 0.9481
# Epoch 5/200
# 760/760 [==============================] - 1s 706us/step - loss: 0.1768 - accuracy: 0.9495 - val_loss: 0.1436 - val_accuracy: 0.9571
# Epoch 6/200
# 760/760 [==============================] - 1s 697us/step - loss: 0.1580 - accuracy: 0.9540 - val_loss: 0.1798 - val_accuracy: 0.9479
# Epoch 7/200
# 760/760 [==============================] - 1s 741us/step - loss: 0.1607 - accuracy: 0.9540 - val_loss: 0.1563 - val_accuracy: 0.9535
# Epoch 8/200
# 760/760 [==============================] - 1s 765us/step - loss: 0.1603 - accuracy: 0.9495 - val_loss: 0.1239 - val_accuracy: 0.9631
# Epoch 9/200
# 760/760 [==============================] - 1s 750us/step - loss: 0.1499 - accuracy: 0.9550 - val_loss: 0.1536 - val_accuracy: 0.9512
# Epoch 10/200
# 760/760 [==============================] - 1s 740us/step - loss: 0.1422 - accuracy: 0.9584 - val_loss: 0.1235 - val_accuracy: 0.9636
# Epoch 11/200
# 760/760 [==============================] - 1s 781us/step - loss: 0.1451 - accuracy: 0.9567 - val_loss: 0.1652 - val_accuracy: 0.9512
# Epoch 12/200
# 760/760 [==============================] - 1s 788us/step - loss: 0.1370 - accuracy: 0.9581 - val_loss: 0.1336 - val_accuracy: 0.9602
# Epoch 13/200
# 760/760 [==============================] - 1s 754us/step - loss: 0.1399 - accuracy: 0.9585 - val_loss: 0.1495 - val_accuracy: 0.9527
# Epoch 14/200
# 760/760 [==============================] - 1s 739us/step - loss: 0.1338 - accuracy: 0.9594 - val_loss: 0.1321 - val_accuracy: 0.9585
# Epoch 15/200
# 760/760 [==============================] - 1s 796us/step - loss: 0.1294 - accuracy: 0.9611 - val_loss: 0.1664 - val_accuracy: 0.9466
# Epoch 16/200
# 760/760 [==============================] - 1s 791us/step - loss: 0.1317 - accuracy: 0.9600 - val_loss: 0.1230 - val_accuracy: 0.9636
# Epoch 17/200
# 760/760 [==============================] - 1s 793us/step - loss: 0.1285 - accuracy: 0.9598 - val_loss: 0.1230 - val_accuracy: 0.9655
# Epoch 18/200
# 760/760 [==============================] - 1s 729us/step - loss: 0.1315 - accuracy: 0.9606 - val_loss: 0.1109 - val_accuracy: 0.9674
# Epoch 19/200
# 760/760 [==============================] - 1s 743us/step - loss: 0.1333 - accuracy: 0.9599 - val_loss: 0.1250 - val_accuracy: 0.9632
# Epoch 20/200
# 760/760 [==============================] - 1s 770us/step - loss: 0.1248 - accuracy: 0.9617 - val_loss: 0.1153 - val_accuracy: 0.9649
# Epoch 21/200
# 760/760 [==============================] - 1s 720us/step - loss: 0.1230 - accuracy: 0.9634 - val_loss: 0.1479 - val_accuracy: 0.9563
# Epoch 22/200
# 760/760 [==============================] - 1s 730us/step - loss: 0.1218 - accuracy: 0.9647 - val_loss: 0.1099 - val_accuracy: 0.9692
# Epoch 23/200
# 760/760 [==============================] - 1s 741us/step - loss: 0.1258 - accuracy: 0.9608 - val_loss: 0.1323 - val_accuracy: 0.9588
# Epoch 24/200
# 760/760 [==============================] - 1s 776us/step - loss: 0.1268 - accuracy: 0.9633 - val_loss: 0.1152 - val_accuracy: 0.9640
# Epoch 25/200
# 760/760 [==============================] - 1s 797us/step - loss: 0.1230 - accuracy: 0.9614 - val_loss: 0.1118 - val_accuracy: 0.9683
# Epoch 26/200
# 760/760 [==============================] - 1s 738us/step - loss: 0.1244 - accuracy: 0.9608 - val_loss: 0.1245 - val_accuracy: 0.9630
# Epoch 27/200
# 760/760 [==============================] - 1s 767us/step - loss: 0.1266 - accuracy: 0.9607 - val_loss: 0.1187 - val_accuracy: 0.9651
# Epoch 28/200
# 760/760 [==============================] - 1s 758us/step - loss: 0.1298 - accuracy: 0.9603 - val_loss: 0.1092 - val_accuracy: 0.9678
# Epoch 29/200
# 760/760 [==============================] - 1s 761us/step - loss: 0.1241 - accuracy: 0.9624 - val_loss: 0.1424 - val_accuracy: 0.9537
# Epoch 30/200
# 760/760 [==============================] - 1s 792us/step - loss: 0.1219 - accuracy: 0.9625 - val_loss: 0.1407 - val_accuracy: 0.9556
# Epoch 31/200
# 760/760 [==============================] - 1s 746us/step - loss: 0.1194 - accuracy: 0.9633 - val_loss: 0.1153 - val_accuracy: 0.9620
# Epoch 32/200
# 760/760 [==============================] - 1s 773us/step - loss: 0.1154 - accuracy: 0.9632 - val_loss: 0.1095 - val_accuracy: 0.9681
# Epoch 33/200
# 760/760 [==============================] - 1s 767us/step - loss: 0.1176 - accuracy: 0.9645 - val_loss: 0.1054 - val_accuracy: 0.9674
# Epoch 34/200
# 760/760 [==============================] - 1s 809us/step - loss: 0.1181 - accuracy: 0.9646 - val_loss: 0.1155 - val_accuracy: 0.9653
# Epoch 35/200
# 760/760 [==============================] - 1s 753us/step - loss: 0.1147 - accuracy: 0.9640 - val_loss: 0.1215 - val_accuracy: 0.9595
# Epoch 36/200
# 760/760 [==============================] - 1s 728us/step - loss: 0.1170 - accuracy: 0.9627 - val_loss: 0.1066 - val_accuracy: 0.9680
# Epoch 37/200
# 760/760 [==============================] - 1s 771us/step - loss: 0.1189 - accuracy: 0.9642 - val_loss: 0.1035 - val_accuracy: 0.9695
# Epoch 38/200
# 760/760 [==============================] - 1s 766us/step - loss: 0.1106 - accuracy: 0.9664 - val_loss: 0.1227 - val_accuracy: 0.9613
# Epoch 39/200
# 760/760 [==============================] - 1s 744us/step - loss: 0.1149 - accuracy: 0.9634 - val_loss: 0.1073 - val_accuracy: 0.9664
# Epoch 40/200
# 760/760 [==============================] - 1s 707us/step - loss: 0.1132 - accuracy: 0.9634 - val_loss: 0.1128 - val_accuracy: 0.9675
# Epoch 41/200
# 760/760 [==============================] - 1s 710us/step - loss: 0.1193 - accuracy: 0.9638 - val_loss: 0.1110 - val_accuracy: 0.9667
# Epoch 42/200
# 760/760 [==============================] - 1s 753us/step - loss: 0.1100 - accuracy: 0.9662 - val_loss: 0.1223 - val_accuracy: 0.9645
# Epoch 43/200
# 760/760 [==============================] - 1s 756us/step - loss: 0.1092 - accuracy: 0.9660 - val_loss: 0.1393 - val_accuracy: 0.9514
# Epoch 44/200
# 760/760 [==============================] - 1s 708us/step - loss: 0.1136 - accuracy: 0.9643 - val_loss: 0.1104 - val_accuracy: 0.9651
# Epoch 45/200
# 760/760 [==============================] - 1s 710us/step - loss: 0.1164 - accuracy: 0.9644 - val_loss: 0.1036 - val_accuracy: 0.9686
# Epoch 46/200
# 760/760 [==============================] - 1s 740us/step - loss: 0.1109 - accuracy: 0.9655 - val_loss: 0.1121 - val_accuracy: 0.9637
# Epoch 47/200
# 760/760 [==============================] - 1s 735us/step - loss: 0.1127 - accuracy: 0.9658 - val_loss: 0.1074 - val_accuracy: 0.9674
# Epoch 48/200
# 760/760 [==============================] - 1s 757us/step - loss: 0.1184 - accuracy: 0.9641 - val_loss: 0.1043 - val_accuracy: 0.9677
# Epoch 49/200
# 760/760 [==============================] - 1s 745us/step - loss: 0.1099 - accuracy: 0.9650 - val_loss: 0.1008 - val_accuracy: 0.9682
# Epoch 50/200
# 760/760 [==============================] - 1s 732us/step - loss: 0.1060 - accuracy: 0.9667 - val_loss: 0.1046 - val_accuracy: 0.9693
# Epoch 51/200
# 760/760 [==============================] - 1s 741us/step - loss: 0.1038 - accuracy: 0.9660 - val_loss: 0.1506 - val_accuracy: 0.9484
# Epoch 52/200
# 760/760 [==============================] - 1s 759us/step - loss: 0.1147 - accuracy: 0.9651 - val_loss: 0.1021 - val_accuracy: 0.9698
# Epoch 53/200
# 760/760 [==============================] - 1s 724us/step - loss: 0.1071 - accuracy: 0.9676 - val_loss: 0.1067 - val_accuracy: 0.9663
# Epoch 54/200
# 760/760 [==============================] - 1s 673us/step - loss: 0.1085 - accuracy: 0.9663 - val_loss: 0.1029 - val_accuracy: 0.9672
# Epoch 55/200
# 760/760 [==============================] - 1s 693us/step - loss: 0.1090 - accuracy: 0.9669 - val_loss: 0.0991 - val_accuracy: 0.9692
# Epoch 56/200
# 760/760 [==============================] - 1s 741us/step - loss: 0.1086 - accuracy: 0.9668 - val_loss: 0.0986 - val_accuracy: 0.9692
# Epoch 57/200
# 760/760 [==============================] - 1s 744us/step - loss: 0.1028 - accuracy: 0.9674 - val_loss: 0.1116 - val_accuracy: 0.9637
# Epoch 58/200
# 760/760 [==============================] - 1s 729us/step - loss: 0.1060 - accuracy: 0.9677 - val_loss: 0.1123 - val_accuracy: 0.9660
# Epoch 59/200
# 760/760 [==============================] - 1s 718us/step - loss: 0.1063 - accuracy: 0.9687 - val_loss: 0.0954 - val_accuracy: 0.9712
# Epoch 60/200
# 760/760 [==============================] - 1s 701us/step - loss: 0.1029 - accuracy: 0.9693 - val_loss: 0.0973 - val_accuracy: 0.9719
# Epoch 61/200
# 760/760 [==============================] - 1s 763us/step - loss: 0.0981 - accuracy: 0.9710 - val_loss: 0.1026 - val_accuracy: 0.9688
# Epoch 62/200
# 760/760 [==============================] - 1s 735us/step - loss: 0.0955 - accuracy: 0.9710 - val_loss: 0.0942 - val_accuracy: 0.9737
# Epoch 63/200
# 760/760 [==============================] - 1s 724us/step - loss: 0.0952 - accuracy: 0.9710 - val_loss: 0.0899 - val_accuracy: 0.9727
# Epoch 64/200
# 760/760 [==============================] - 1s 767us/step - loss: 0.0985 - accuracy: 0.9688 - val_loss: 0.0897 - val_accuracy: 0.9756
# Epoch 65/200
# 760/760 [==============================] - 1s 759us/step - loss: 0.0920 - accuracy: 0.9723 - val_loss: 0.0927 - val_accuracy: 0.9711
# Epoch 66/200
# 760/760 [==============================] - 1s 742us/step - loss: 0.0926 - accuracy: 0.9729 - val_loss: 0.1157 - val_accuracy: 0.9616
# Epoch 67/200
# 760/760 [==============================] - 1s 731us/step - loss: 0.0925 - accuracy: 0.9714 - val_loss: 0.0871 - val_accuracy: 0.9762
# Epoch 68/200
# 760/760 [==============================] - 1s 771us/step - loss: 0.0912 - accuracy: 0.9737 - val_loss: 0.0961 - val_accuracy: 0.9744
# Epoch 69/200
# 760/760 [==============================] - 1s 802us/step - loss: 0.1040 - accuracy: 0.9696 - val_loss: 0.0847 - val_accuracy: 0.9753
# Epoch 70/200
# 760/760 [==============================] - 1s 858us/step - loss: 0.0908 - accuracy: 0.9718 - val_loss: 0.0942 - val_accuracy: 0.9711
# Epoch 71/200
# 760/760 [==============================] - 1s 845us/step - loss: 0.0899 - accuracy: 0.9727 - val_loss: 0.0816 - val_accuracy: 0.9761
# Epoch 72/200
# 760/760 [==============================] - 1s 853us/step - loss: 0.0920 - accuracy: 0.9726 - val_loss: 0.0952 - val_accuracy: 0.9734
# Epoch 73/200
# 760/760 [==============================] - 1s 786us/step - loss: 0.0894 - accuracy: 0.9743 - val_loss: 0.0866 - val_accuracy: 0.9762
# Epoch 74/200
# 760/760 [==============================] - 1s 721us/step - loss: 0.0949 - accuracy: 0.9726 - val_loss: 0.0877 - val_accuracy: 0.9755
# Epoch 75/200
# 760/760 [==============================] - 1s 733us/step - loss: 0.0916 - accuracy: 0.9713 - val_loss: 0.0803 - val_accuracy: 0.9766
# Epoch 76/200
# 760/760 [==============================] - 1s 719us/step - loss: 0.0879 - accuracy: 0.9739 - val_loss: 0.0887 - val_accuracy: 0.9742
# Epoch 77/200
# 760/760 [==============================] - 1s 781us/step - loss: 0.0919 - accuracy: 0.9730 - val_loss: 0.1091 - val_accuracy: 0.9666
# Epoch 78/200
# 760/760 [==============================] - 1s 804us/step - loss: 0.0965 - accuracy: 0.9719 - val_loss: 0.1002 - val_accuracy: 0.9698
# Epoch 79/200
# 760/760 [==============================] - 1s 792us/step - loss: 0.0943 - accuracy: 0.9715 - val_loss: 0.0976 - val_accuracy: 0.9738
# Epoch 80/200
# 760/760 [==============================] - 1s 840us/step - loss: 0.0905 - accuracy: 0.9725 - val_loss: 0.0833 - val_accuracy: 0.9766
# Epoch 81/200
# 760/760 [==============================] - 1s 784us/step - loss: 0.0914 - accuracy: 0.9733 - val_loss: 0.0842 - val_accuracy: 0.9757
# Epoch 82/200
# 760/760 [==============================] - 1s 754us/step - loss: 0.0925 - accuracy: 0.9722 - val_loss: 0.0928 - val_accuracy: 0.9731
# Epoch 83/200
# 760/760 [==============================] - 1s 798us/step - loss: 0.0879 - accuracy: 0.9745 - val_loss: 0.0991 - val_accuracy: 0.9738
# Epoch 84/200
# 760/760 [==============================] - 1s 746us/step - loss: 0.0914 - accuracy: 0.9746 - val_loss: 0.0809 - val_accuracy: 0.9777
# Epoch 85/200
# 760/760 [==============================] - 1s 764us/step - loss: 0.0889 - accuracy: 0.9740 - val_loss: 0.0954 - val_accuracy: 0.9720
# Epoch 86/200
# 760/760 [==============================] - 1s 774us/step - loss: 0.0886 - accuracy: 0.9745 - val_loss: 0.0784 - val_accuracy: 0.9761
# Epoch 87/200
# 760/760 [==============================] - 1s 721us/step - loss: 0.0849 - accuracy: 0.9756 - val_loss: 0.0931 - val_accuracy: 0.9749
# Epoch 88/200
# 760/760 [==============================] - 1s 758us/step - loss: 0.0902 - accuracy: 0.9726 - val_loss: 0.0838 - val_accuracy: 0.9757
# Epoch 89/200
# 760/760 [==============================] - 1s 738us/step - loss: 0.0884 - accuracy: 0.9736 - val_loss: 0.0831 - val_accuracy: 0.9765
# Epoch 90/200
# 760/760 [==============================] - 1s 730us/step - loss: 0.0874 - accuracy: 0.9746 - val_loss: 0.0771 - val_accuracy: 0.9765
# Epoch 91/200
# 760/760 [==============================] - 1s 719us/step - loss: 0.0836 - accuracy: 0.9756 - val_loss: 0.0874 - val_accuracy: 0.9751
# Epoch 92/200
# 760/760 [==============================] - 1s 765us/step - loss: 0.0866 - accuracy: 0.9754 - val_loss: 0.0851 - val_accuracy: 0.9734
# Epoch 93/200
# 760/760 [==============================] - 1s 812us/step - loss: 0.0863 - accuracy: 0.9739 - val_loss: 0.0823 - val_accuracy: 0.9748
# Epoch 94/200
# 760/760 [==============================] - 1s 794us/step - loss: 0.0820 - accuracy: 0.9759 - val_loss: 0.0831 - val_accuracy: 0.9772
# Epoch 95/200
# 760/760 [==============================] - 1s 734us/step - loss: 0.0862 - accuracy: 0.9738 - val_loss: 0.0797 - val_accuracy: 0.9775
# Epoch 96/200
# 760/760 [==============================] - 1s 794us/step - loss: 0.0884 - accuracy: 0.9742 - val_loss: 0.0911 - val_accuracy: 0.9712
# Epoch 97/200
# 760/760 [==============================] - 1s 809us/step - loss: 0.0918 - accuracy: 0.9735 - val_loss: 0.0784 - val_accuracy: 0.9766
# Epoch 98/200
# 760/760 [==============================] - 1s 781us/step - loss: 0.0842 - accuracy: 0.9753 - val_loss: 0.0838 - val_accuracy: 0.9757
# Epoch 99/200
# 760/760 [==============================] - 1s 852us/step - loss: 0.0900 - accuracy: 0.9744 - val_loss: 0.0853 - val_accuracy: 0.9757
# Epoch 100/200
# 760/760 [==============================] - 1s 818us/step - loss: 0.0904 - accuracy: 0.9737 - val_loss: 0.0827 - val_accuracy: 0.9770
# Epoch 101/200
# 760/760 [==============================] - 1s 817us/step - loss: 0.0821 - accuracy: 0.9751 - val_loss: 0.0786 - val_accuracy: 0.9771
# Epoch 102/200
# 760/760 [==============================] - 1s 810us/step - loss: 0.0872 - accuracy: 0.9746 - val_loss: 0.0833 - val_accuracy: 0.9771
# Epoch 103/200
# 760/760 [==============================] - 1s 847us/step - loss: 0.0832 - accuracy: 0.9765 - val_loss: 0.0830 - val_accuracy: 0.9753
# Epoch 104/200
# 760/760 [==============================] - 1s 873us/step - loss: 0.0820 - accuracy: 0.9760 - val_loss: 0.0763 - val_accuracy: 0.9785
# Epoch 105/200
# 760/760 [==============================] - 1s 801us/step - loss: 0.0827 - accuracy: 0.9753 - val_loss: 0.0806 - val_accuracy: 0.9762
# Epoch 106/200
# 760/760 [==============================] - 1s 801us/step - loss: 0.0906 - accuracy: 0.9735 - val_loss: 0.0801 - val_accuracy: 0.9766
# Epoch 107/200
# 760/760 [==============================] - 1s 798us/step - loss: 0.0856 - accuracy: 0.9757 - val_loss: 0.0763 - val_accuracy: 0.9780
# Epoch 108/200
# 760/760 [==============================] - 1s 806us/step - loss: 0.0821 - accuracy: 0.9764 - val_loss: 0.0839 - val_accuracy: 0.9744
# Epoch 109/200
# 760/760 [==============================] - 1s 844us/step - loss: 0.0812 - accuracy: 0.9756 - val_loss: 0.0798 - val_accuracy: 0.9771
# Epoch 110/200
# 760/760 [==============================] - 1s 832us/step - loss: 0.0864 - accuracy: 0.9760 - val_loss: 0.0950 - val_accuracy: 0.9692
# Epoch 111/200
# 760/760 [==============================] - 1s 773us/step - loss: 0.0862 - accuracy: 0.9755 - val_loss: 0.0852 - val_accuracy: 0.9752
# Epoch 112/200
# 760/760 [==============================] - 1s 832us/step - loss: 0.0849 - accuracy: 0.9744 - val_loss: 0.1040 - val_accuracy: 0.9669
# Epoch 113/200
# 760/760 [==============================] - 1s 828us/step - loss: 0.0910 - accuracy: 0.9726 - val_loss: 0.0797 - val_accuracy: 0.9768
# Epoch 114/200
# 760/760 [==============================] - 1s 805us/step - loss: 0.0817 - accuracy: 0.9764 - val_loss: 0.0821 - val_accuracy: 0.9775
# Epoch 115/200
# 760/760 [==============================] - 1s 813us/step - loss: 0.0836 - accuracy: 0.9749 - val_loss: 0.0788 - val_accuracy: 0.9762
# Epoch 116/200
# 760/760 [==============================] - 1s 805us/step - loss: 0.0865 - accuracy: 0.9742 - val_loss: 0.0769 - val_accuracy: 0.9772
# Epoch 117/200
# 760/760 [==============================] - 1s 829us/step - loss: 0.0827 - accuracy: 0.9749 - val_loss: 0.0766 - val_accuracy: 0.9785
# Epoch 118/200
# 760/760 [==============================] - 1s 891us/step - loss: 0.0812 - accuracy: 0.9758 - val_loss: 0.0774 - val_accuracy: 0.9771
# Epoch 119/200
# 760/760 [==============================] - 1s 847us/step - loss: 0.0868 - accuracy: 0.9744 - val_loss: 0.0875 - val_accuracy: 0.9728
# Epoch 120/200
# 760/760 [==============================] - 1s 814us/step - loss: 0.0785 - accuracy: 0.9772 - val_loss: 0.0889 - val_accuracy: 0.9725
# Epoch 121/200
# 760/760 [==============================] - 1s 838us/step - loss: 0.0936 - accuracy: 0.9731 - val_loss: 0.0770 - val_accuracy: 0.9769
# Epoch 122/200
# 760/760 [==============================] - 1s 832us/step - loss: 0.0845 - accuracy: 0.9762 - val_loss: 0.0770 - val_accuracy: 0.9765
# Epoch 123/200
# 760/760 [==============================] - 1s 825us/step - loss: 0.0789 - accuracy: 0.9780 - val_loss: 0.0837 - val_accuracy: 0.9751
# Epoch 124/200
# 760/760 [==============================] - 1s 805us/step - loss: 0.0832 - accuracy: 0.9743 - val_loss: 0.0823 - val_accuracy: 0.9766

# %%
plt.plot(history.history['val_loss'],label="val loss")
plt.plot(history.history['loss'],label="loss")
plt.legend()

# %load_ext tensorboard
#rm -rf ./logs/
# %tensorboard --logdir logs/fit
# Out:
# ERROR: Could not find `tensorboard`. Please ensure that your PATH
# contains an executable `tensorboard` program, or explicitly specify
# the path to a TensorBoard binary by setting the `TENSORBOARD_BINARY`
# environment variable.

# %% [markdown]
# ## Create and train a Boosted Decision Tree
# Here, instead of using a MLP, we use a [_Gradient Boosted Decision Tree_](https://xgboost.readthedocs.io/en/stable/) (BDT) to distinguish between signal (true CE hits) and background (fake CE hits). We use the defualt hyperparameters.

# %%
model_xgboost = XGBClassifier(use_label_encoder=False)
model_xgboost.fit(x_ce_train, y_ce_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %% [markdown]
# Here we can finally apply our two models (the MLP and the BDT) to our test datasets and create the corresponding ROC curves.

# %%
#prediction_ce = model.predict(x_ce_test).ravel()
prediction_ce = model.predict(x_ce_test)
fpr_ce, tpr_ce, th_ce = roc_curve(y_ce_test,  prediction_ce)
auc_ce = roc_auc_score(y_ce_test, prediction_ce)

# %%
prediction_xgboost = model_xgboost.predict_proba(x_ce_test)[:,1]
fpr_xgboost, tpr_xgboost, th_xgboost = roc_curve(y_ce_test,  prediction_xgboost)
auc_xgboost = roc_auc_score(y_ce_test, prediction_xgboost)

# %% [markdown]
# The plot of the ROC curves clearly shows that the BDT outperforms the MLP. In principle, however, it should be possible to improve the MLP performances by optimizing the hyperparameters (learning rate, hidden layers, activation functions, etc.).

# %%
fig, ax = plt.subplots(1,1)
ax.plot(tpr_ce,1-fpr_ce,label=f'MLP AUC: {auc_ce:.4f}')
ax.plot(tpr_xgboost,1-fpr_xgboost,label=f'BDT AUC: {auc_xgboost:.4f}')

ax.legend()
ax.set_aspect("equal")
ax.set_xlabel("Signal efficiency")
ax.set_ylabel("Background rejection")
ax.set_xlim(0.8,1.05)
ax.set_ylim(0.8,1.05)

fig.savefig("plots/TrainBkg" + suffix + ".pdf")

# %% [markdown]
# Now we save our model in HDF5 format.  This can be used as input to the SOFIE parser.  Note that the kernel must be restarted when saving this file, as re-running individual cells increments the layer numbers in the hdf5 file, causing the SOFIE parser to fail.  This causes the spurious tensorflow warning about the model not having been built.

# %%
model.save(modelfile)
print("model saved to " +modelfile)
model.summary()
# Out:
# model saved to models/TrainBkgnewdata.h5
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(32, 6)]                 0
# _________________________________________________________________
# dense_4 (Dense)              (32, 12)                  84
# _________________________________________________________________
# dense_5 (Dense)              (32, 12)                  156
# _________________________________________________________________
# dense_6 (Dense)              (32, 12)                  156
# _________________________________________________________________
# dense_7 (Dense)              (32, 1)                   13
# =================================================================
# Total params: 409
# Trainable params: 409
# Non-trainable params: 0
# _________________________________________________________________
