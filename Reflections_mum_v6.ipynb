# %% [markdown]
# # Reflecting Cosmic Ray analysis
# This notebook analyzes pairs of tracks from simulated cosmic ray events, comparing upstream and downstream properties to extract the momentum resolution and shift due to material effects.
# It uses root, uproot, and standard python numerical and plotting packages.

# %% [markdown]
# This notebook processes TrkAna files constructed using the SelectReflections_module filter.
# The TrkAna files contain 4 trees, one for each particle type reconstruction assumption: e+, e-, mu+, and mu-.
# Each tree has the same structure, consisting of 2 tracks reconstructed from this particle: trk[0] is the upstream-going fit, trk[1] is the downstream-going fit.

# %%
#files = ["/global/cfs/cdirs/m3712/Mu2e/TARef_v7.root:TARmuM/trkana"]
#files = ["/Users/brownd/data/14356147/nts.brownd.TAReflect.TARef.001202_00004963.root:TARmuM/trkana",
#         "/Users/brownd/data/14356147/nts.brownd.TAReflect.TARef.001202_00015026.root:TARmuM/trkana",
#        "/Users/brownd/data/14356147/nts.brownd.TAReflect.TARef.001202_00005432.root:TARmuM/trkana",
#        "/Users/brownd/data/14356147/nts.brownd.TAReflect.TARef.001202_00000000.root:TARmuM/trkana",
#        "/Users/brownd/data/14356147/nts.brownd.TAReflect.TARef.001202_00000010.root:TARmuM/trkana",
#        "/Users/brownd/data/14356147/nts.brownd.TAReflect.TARef.001202_00000085.root:TARmuM/trkana",
#        "/Users/brownd/data/14356147/nts.brownd.TAReflect.TARef.001202_00010872.root:TARmuM/trkana",
#        "/Users/brownd/data/14356147/nts.brownd.TAReflect.TARef.001202_00000053.root:TARmuM/trkana",
#        "/Users/brownd/data/14356147/nts.brownd.TAReflect.TARef.001202_00000024.root:TARmuM/trkana",
#        "/Users/brownd/data/14356147/nts.brownd.TAReflect.TARef.001202_00010057.root:TARmuM/trkana"]
#files = [ "/Users/brownd/data/TARef_t00.root:TARmuM/ntuple"]
files = [ "/data/HD5/users/brownd/71077187/nts.brownd.TAReflect.TARef.001202_00000000.root:TARmuM/ntuple",
"/data/HD5/users/brownd/71077187/nts.brownd.TAReflect.TARef.001202_00000010.root:TARmuM/ntuple",
"/data/HD5/users/brownd/71077187/nts.brownd.TAReflect.TARef.001202_00000024.root:TARmuM/ntuple",
"/data/HD5/users/brownd/71077187/nts.brownd.TAReflect.TARef.001202_00000053.root:TARmuM/ntuple",
"/data/HD5/users/brownd/71077187/nts.brownd.TAReflect.TARef.001202_00000085.root:TARmuM/ntuple",
"/data/HD5/users/brownd/71077187/nts.brownd.TAReflect.TARef.001202_00004963.root:TARmuM/ntuple",
"/data/HD5/users/brownd/71077187/nts.brownd.TAReflect.TARef.001202_00005432.root:TARmuM/ntuple",
"/data/HD5/users/brownd/71077187/nts.brownd.TAReflect.TARef.001202_00010057.root:TARmuM/ntuple",
"/data/HD5/users/brownd/71077187/nts.brownd.TAReflect.TARef.001202_00010872.root:TARmuM/ntuple",
"/data/HD5/users/brownd/71077187/nts.brownd.TAReflect.TARef.001202_00015026.root:TARmuM/ntuple" ]
particle = "muon"
plabel = "$\\mu^-$"

# %%
# %run Reflections_v6.ipynb
# Out:
# Hello world
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  3115  downstream  3115
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  1242  downstream  1242
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  3103  downstream  3103
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  1373  downstream  1373
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  3092  downstream  3092
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  1388  downstream  1388
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  3122  downstream  3122
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  1487  downstream  1487
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  1681  downstream  1681
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  3092  downstream  3092
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  1554  downstream  1554
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  3098  downstream  3098
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  1119  downstream  1119
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  3121  downstream  3121
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  2011  downstream  2011
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  3130  downstream  3130
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  1583  downstream  1583
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  3092  downstream  3092
# Fields available in 'trksegs': ['mom', 'pos', 'time', 'dmom', 'momerr', 'inbounds', 'gap', 'early', 'late', 'sid', 'sindex']
# uspstream  946  downstream  946
# Upstream momentum  42345 [104.395386 115.99074  118.318756 113.83976  141.90562   91.906364
#  170.2609   151.67757  158.57562   97.06032 ]
# Downstream momentum  42345 [103.15345  115.594154 118.85252  112.664505 141.6406    90.05909
#  170.55399  152.20413  158.72725   97.64256 ]
# Upstream fit upstream time  42345 [np.float64(1184.307070889032), np.float64(1560.8805061597313), np.float64(993.1524495751563), np.float64(1359.262526436836), np.float64(1528.868110914745), np.float64(1189.492670266003), np.float64(457.70584745731765), np.float64(1459.3671725961674), np.float64(548.1306561666113), np.float64(1318.0149210007835)]
# Upstream fit downstream time 42345 [np.float64(1251.160589182181), np.float64(1638.3762790638445), np.float64(1061.9480112557985), np.float64(1430.9050197110093), np.float64(1599.1534320778387), np.float64(1270.3049284450078), np.float64(526.6464789388148), np.float64(1520.8461854545983), np.float64(620.2321325151497), np.float64(1412.4762482837343)]
# Downstream fit downstream time 42345 [np.float64(1251.3299715982212), np.float64(1637.4374263450852), np.float64(1062.0652750439592), np.float64(1430.8949389736392), np.float64(1599.1741820185434), np.float64(1274.4058744868112), np.float64(526.389073313955), np.float64(1520.7231602183635), np.float64(621.4224674584573), np.float64(1410.5058085146675)]
# Upstream MC PDG code 42345 [np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13)]
# Downstream MC PDG code 42345 [np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13), np.int32(13)]
# Decays  41
# nmat  42345
# N ST  [0 6 0 0 0 1 0 0 0 1]  N IPA  [7 3 4 3 4 4 0 0 2 3] N mat  [7 9 4 3 4 5 0 0 2 4]
# True Electrons 42345 [False False False False False False False False False False]
# True Muons 42345 [ True  True  True  True  True  True  True  True  True  True]
# True Particles 42345 [ True  True  True  True  True  True  True  True  True  True]
# N true electrons  1243  N true muons  41092
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2341632/1849974898.py:6: SyntaxWarning: invalid escape sequence '\D'
#   ehist = ax.hist(em_time_diff,label="True $e^-$ $\Delta$ T", bins=100,range=(-25,25))
# /tmp/ipykernel_2341632/1849974898.py:7: SyntaxWarning: invalid escape sequence '\m'
#   muhist = ax.hist(mum_time_diff,label="True $\mu^-$ $\Delta$ T", bins=100,range=(-25,25))
# Good Delta T  42345 [ True  True  True  True  True  True  True  True  True  True]
# For Delta T <  5.0  efficiency =  0.9203007884746423  purity =  0.9999471137319195
# nomat  42345
